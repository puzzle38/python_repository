# %%
# !pip install jupyter_contrib_nbextensions
# Out:
# ...
#      --------------------------------------- 23.5/23.5 MB 17.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 481.7/481.7 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for jupyter_contrib_nbextensions: filename=jupyter_contrib_nbextensions-0.7.0-py2.py3-none-any.whl size=23428786 sha256=a2d220351c9669a56d438b4c56e1c4f2053a420aeab1e12327b9b688689532d9
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\88\a0\bc\cc7955eb4114404f871d149598d2f37104b0d0692d5357cc41
# ...
#   Created wheel for jupyter_contrib_core: filename=jupyter_contrib_core-0.4.2-py2.py3-none-any.whl size=17484 sha256=086b5e8b86f8b4dc5b89b4abaecb8bbeeba70f0a1633c885a4fd3e24d6e7b547
# ...

# %%
# !pip install jupytext
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\anaconda3\lib\site-packages)

# %%
# !jupyter notebook --generate-config
