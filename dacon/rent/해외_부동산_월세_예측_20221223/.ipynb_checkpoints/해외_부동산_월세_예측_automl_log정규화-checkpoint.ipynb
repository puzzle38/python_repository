# %% [markdown]
# # 라이브러리 불러오기

# %%
import random
import os
import sys

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import OneHotEncoder

from supervised.automl import AutoML

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## 버젼 확인하기

# %%
print("python version : ", sys.version)
print("pandas version : ", pd.__version__)
print("numpy version : ", np.__version__)
print("seaborn version : ", sns.__version__)
print("scikit version : ", sklearn.__version__)
# Out:
# python version :  3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]
# pandas version :  1.4.2
# numpy version :  1.21.4
# seaborn version :  0.11.2
# scikit version :  1.0.2

# %% [markdown]
# ## 시드 고정

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(38) # Seed 고정

# %% [markdown]
# # 데이터 불러오기

# %%
train = pd.read_csv('C:/Users/user/python_repository/dacon/rent/data/train.csv')
test = pd.read_csv('C:/Users/user/python_repository/dacon/rent/data/test.csv')
submission = pd.read_csv('C:/Users/user/python_repository/dacon/rent/data/sample_submission.csv')

# %% [markdown]
# # EDA

# %%
# EDA용 df 데이터셋 생성
total_df = train.drop(columns = ['ID'])
#qualitative: 질적 변수
qual_df = total_df[['propertyType', 'suburbName']]
#quantitative: 양적 변수
quan_df = total_df.drop(columns = ['propertyType', 'suburbName'])

# %% [markdown]
# ## 결측치 확인

# %%
train.isnull().sum()
# Out:
# ID                        0
# propertyType              0
# bedrooms                  0
# latitude                  0
# longitude                 0
# suburbName                0
# distanceMetro(km)         0
# distanceAirport(km)       0
# distanceHospital(km)      0
# distanceRailway(km)       0
# area(square_meters)       0
# monthlyRent(us_dollar)    0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# ID                      0
# propertyType            0
# bedrooms                0
# latitude                0
# longitude               0
# suburbName              0
# distanceMetro(km)       0
# distanceAirport(km)     0
# distanceHospital(km)    0
# distanceRailway(km)     0
# area(square_meters)     0
# dtype: int64

# %% [markdown]
# ## 양적변수

# %%
# 양적변수 기초통계량 확인
total_df.describe()
# Out:
#           bedrooms     latitude    longitude  distanceMetro(km)  \
# count  8692.000000  8692.000000  8692.000000        8692.000000
# mean      2.119650    28.611199    77.167464           0.869998
# std       0.900757     0.070853     0.093600           1.261337
# min       1.000000    26.467743    76.742523           0.002892
# 25%       1.000000    28.563490    77.102028           0.459687
# 50%       2.000000    28.616885    77.168053           0.698592
# 75%       3.000000    28.651827    77.224998           1.092694
# max       8.000000    28.872597    80.339027          65.866623
#
#        distanceAirport(km)  distanceHospital(km)  distanceRailway(km)  \
# count          8692.000000           8692.000000          8692.000000
# mean             13.699359             11.373803            11.419991
# std               7.926709              7.500915             7.345131
# min               1.901789              0.669150             0.722023
# 25%              11.152285              8.167231             8.075549
# 50%              13.139656             10.922441            11.244344
# 75%              17.225196             15.548549            15.435535
# max             396.043067            387.016246           390.969378
#
#        area(square_meters)  monthlyRent(us_dollar)
# count          8692.000000             8692.000000
# mean            101.990737              321.376898
# std              59.355027              230.962181
# min               9.290000               14.000000
# 25%              55.740000              159.000000
# 50%              83.610000              258.000000
# 75%             139.350000              393.000000
# max             882.580000             1476.000000

# %%
#양적 변수 분포 시각화
quan_df.hist(bins=100, figsize=(18,18))
plt.show()

# %% [markdown]
# ## 질적변수

# %%
#질적 변수 빈도 시각화
fig, axes = plt.subplots(2, 1, figsize=(20,15))

sns.countplot(x = qual_df['propertyType'], ax=axes[0])
sns.countplot(x = qual_df['suburbName'], ax=axes[1])

plt.show()

# %% [markdown]
# ## 이상치 확인

# %%
#이상치 확인
fig, axes = plt.subplots(3,3, figsize=(15,15))

sns.boxplot(y = quan_df['bedrooms'], ax=axes[0][0])
sns.boxplot(y = quan_df['latitude'], ax=axes[0][1])
sns.boxplot(y = quan_df['longitude'], ax=axes[0][2])

sns.boxplot(y = quan_df['distanceMetro(km)'], ax=axes[1][0])
sns.boxplot(y = quan_df['distanceAirport(km)'], ax=axes[1][1])
sns.boxplot(y = quan_df['distanceHospital(km)'], ax=axes[1][2])

sns.boxplot(y = quan_df['distanceRailway(km)'], ax=axes[2][0])
sns.boxplot(y = quan_df['area(square_meters)'], ax=axes[2][1])
sns.boxplot(y = quan_df['monthlyRent(us_dollar)'], ax=axes[2][2])

plt.show()

# %% [markdown]
# ## 상관관계

# %%
#상관관계 히트맵
plt.figure(figsize = (15,15))
sns.heatmap(quan_df.corr(), annot = True, fmt = '.1f', linewidth = 1, cmap = 'Blues')

plt.show()

# %% [markdown]
# # 전처리

# %% [markdown]
# ## 변수명 조정

# %%
# ID와 타겟 컬럼 제거
x_train = train.drop(columns=['ID', 'monthlyRent(us_dollar)'])
y_train = train['monthlyRent(us_dollar)']
x_test = test.drop(columns=['ID'])

# %%
# North Delhi -> Delhi North 로 통일
# West Delhi -> Delhi West 로 통일
x_train.loc[x_train['suburbName']=='North Delhi','suburbName']='Delhi North'
x_train.loc[x_train['suburbName']=='West Delhi','suburbName']='Delhi West'
x_test.loc[x_test['suburbName']=='North Delhi','suburbName']='Delhi North'
x_test.loc[x_test['suburbName']=='West Delhi','suburbName']='Delhi West'

# %%
plt.figure(figsize=(15,15))
sns.countplot(x = x_train['suburbName'])
plt.show()

# %% [markdown]
# ## One-Hot 인코딩

# %%
# qualitative column one-hot encoding
qual_col = ['propertyType','suburbName']
ohe = OneHotEncoder(sparse=False)

for i in qual_col:
    x_train = pd.concat([x_train, pd.DataFrame(ohe.fit_transform(x_train[[i]]), columns=ohe.categories_[0])], axis=1)
    
    for qual_value in np.unique(x_test[i]): 
        if qual_value not in np.unique(ohe.categories_): 
            ohe.categories_ = np.append(ohe.categories_, qual_value)
    # One Hot Encoder가 Test 데이터로부터 Fitting되는 것은 Data Leakage이므로, Test 데이터에는 Train 데이터로 Fitting된 One Hot Encoder로부터 transform만 수행되어야 합니다.
    x_test = pd.concat([x_test, pd.DataFrame(ohe.transform(x_test[[i]]), columns=ohe.categories_[0])], axis=1)

# %%
x_train = x_train.drop(columns=['propertyType','suburbName'])
x_test = x_test.drop(columns=['propertyType','suburbName'])

# %% [markdown]
# ## 로그 정규화

# %%
x_train.loc[:,:'area(square_meters)'] = np.log1p(x_train.loc[:,:'area(square_meters)'])
x_test.loc[:,:'area(square_meters)'] = np.log1p(x_test.loc[:,:'area(square_meters)'])

# %% [markdown]
# # 모델링

# %% [markdown]
# ## AutoML

# %%
# 검증옵션
val_strategy = {
    'validation_type' : 'kfold',
    'k_folds' : 5,
    'shuffle' : True,
    "stratify": True
}

# %%
# automl 모델 생성
automl = AutoML(mode = 'Compete', eval_metric='mae', ml_task='regression', n_jobs=-1, validation_strategy=val_strategy)
automl.fit(x_train, y_train)
# Out:
# AutoML directory: AutoML_1
# The task is regression with evaluation metric mae
# AutoML will use algorithms: ['Decision Tree', 'Linear', 'Random Forest', 'Extra Trees', 'LightGBM', 'Xgboost', 'CatBoost', 'Neural Network', 'Nearest Neighbors']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step simple_algorithms will try to check up to 4 models
# 1_DecisionTree mae 84.339544 trained in 0.81 seconds
# 2_DecisionTree mae 78.803097 trained in 0.75 seconds
# 3_DecisionTree mae 78.803097 trained in 0.79 seconds
# 4_Linear mae 73.428017 trained in 1.87 seconds
# * Step default_algorithms will try to check up to 7 models
# 5_Default_LightGBM mae 56.548433 trained in 3.24 seconds
# 6_Default_Xgboost mae 57.078882 trained in 3.49 seconds
# 7_Default_CatBoost mae 56.520717 trained in 8.78 seconds
# 8_Default_NeuralNetwork mae 64.425376 trained in 3.08 seconds
# 9_Default_RandomForest mae 72.505836 trained in 3.65 seconds
# 10_Default_ExtraTrees mae 82.671419 trained in 2.77 seconds
# There was an error during 11_Default_NearestNeighbors training.
# Please check AutoML_1\errors.md for details.
# * Step not_so_random will try to check up to 63 models
# 20_LightGBM mae 57.300173 trained in 3.58 seconds
# 11_Xgboost mae 57.029632 trained in 3.63 seconds
# 29_CatBoost mae 55.785595 trained in 67.85 seconds
# 38_RandomForest mae 72.819768 trained in 3.84 seconds
# 47_ExtraTrees mae 91.942426 trained in 4.6 seconds
# 56_NeuralNetwork mae 65.671487 trained in 3.31 seconds
# There was an error during 65_NearestNeighbors training.
# Please check AutoML_1\errors.md for details.
# 21_LightGBM mae 57.241854 trained in 2.02 seconds
# 12_Xgboost mae 57.006323 trained in 3.34 seconds
# 30_CatBoost mae 55.771231 trained in 12.35 seconds
# 39_RandomForest mae 79.475491 trained in 4.37 seconds
# 48_ExtraTrees mae 90.85257 trained in 2.65 seconds
# 57_NeuralNetwork mae 64.757794 trained in 6.43 seconds
# There was an error during 66_NearestNeighbors training.
# Please check AutoML_1\errors.md for details.
# 22_LightGBM mae 56.645462 trained in 3.77 seconds
# 13_Xgboost mae 56.930927 trained in 3.75 seconds
# 31_CatBoost mae 56.089662 trained in 10.1 seconds
# 40_RandomForest mae 65.368489 trained in 4.67 seconds
# 49_ExtraTrees mae 70.659921 trained in 4.06 seconds
# 58_NeuralNetwork mae 66.596448 trained in 5.41 seconds
# There was an error during 67_NearestNeighbors training.
# Please check AutoML_1\errors.md for details.
# 23_LightGBM mae 56.998488 trained in 3.83 seconds
# 14_Xgboost mae 57.916245 trained in 3.43 seconds
# 32_CatBoost mae 57.288541 trained in 9.0 seconds
# 41_RandomForest mae 64.846273 trained in 5.57 seconds
# 50_ExtraTrees mae 74.284846 trained in 3.94 seconds
# 59_NeuralNetwork mae 64.673961 trained in 4.44 seconds
# There was an error during 68_NearestNeighbors training.
# Please check AutoML_1\errors.md for details.
# 24_LightGBM mae 57.094523 trained in 2.51 seconds
# 15_Xgboost mae 57.14166 trained in 4.36 seconds
# 33_CatBoost mae 56.485165 trained in 12.2 seconds
# 42_RandomForest mae 62.454216 trained in 5.83 seconds
# 51_ExtraTrees mae 69.476061 trained in 4.92 seconds
# 60_NeuralNetwork mae 63.083958 trained in 8.21 seconds
# There was an error during 69_NearestNeighbors training.
# Please check AutoML_1\errors.md for details.
# 25_LightGBM mae 56.780128 trained in 4.48 seconds
# 16_Xgboost mae 57.882293 trained in 4.97 seconds
# 34_CatBoost mae 57.422893 trained in 13.06 seconds
# 43_RandomForest mae 63.31464 trained in 5.63 seconds
# 52_ExtraTrees mae 67.557577 trained in 5.29 seconds
# 61_NeuralNetwork mae 63.644616 trained in 7.61 seconds
# There was an error during 70_NearestNeighbors training.
# Please check AutoML_1\errors.md for details.
# 26_LightGBM mae 56.759659 trained in 4.66 seconds
# 17_Xgboost mae 56.489376 trained in 5.06 seconds
# 35_CatBoost mae 55.785914 trained in 34.59 seconds
# 44_RandomForest mae 72.079049 trained in 4.53 seconds
# 53_ExtraTrees mae 83.141798 trained in 3.72 seconds
# 62_NeuralNetwork mae 63.928416 trained in 5.37 seconds
# There was an error during 71_NearestNeighbors training.
# Please check AutoML_1\errors.md for details.
# 27_LightGBM mae 57.098519 trained in 3.58 seconds
# 18_Xgboost mae 57.585857 trained in 4.97 seconds
# 36_CatBoost mae 56.038866 trained in 13.14 seconds
# 45_RandomForest mae 72.195283 trained in 4.89 seconds
# 54_ExtraTrees mae 85.308353 trained in 3.72 seconds
# 63_NeuralNetwork mae 66.562531 trained in 6.4 seconds
# There was an error during 72_NearestNeighbors training.
# Please check AutoML_1\errors.md for details.
# 28_LightGBM mae 57.197718 trained in 4.47 seconds
# 19_Xgboost mae 56.182885 trained in 6.23 seconds
# 37_CatBoost mae 55.800563 trained in 46.67 seconds
# 46_RandomForest mae 62.148349 trained in 7.02 seconds
# 55_ExtraTrees mae 71.864562 trained in 5.27 seconds
# 64_NeuralNetwork mae 67.248603 trained in 4.27 seconds
# There was an error during 73_NearestNeighbors training.
# Please check AutoML_1\errors.md for details.
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: area(square_meters)_multiply_longitude
# Add Golden Feature: area(square_meters)_sum_longitude
# Add Golden Feature: area(square_meters)_multiply_latitude
# Add Golden Feature: area(square_meters)_sum_latitude
# Add Golden Feature: longitude_ratio_area(square_meters)
# Add Golden Feature: longitude_diff_area(square_meters)
# Add Golden Feature: area(square_meters)_ratio_longitude
# Add Golden Feature: latitude_diff_area(square_meters)
# Add Golden Feature: area(square_meters)_ratio_latitude
# Add Golden Feature: latitude_ratio_area(square_meters)
# Created 10 Golden Features in 12.16 seconds.
# 30_CatBoost_GoldenFeatures mae 56.169357 trained in 33.12 seconds
# 29_CatBoost_GoldenFeatures mae 55.580521 trained in 139.64 seconds
# 35_CatBoost_GoldenFeatures mae 55.850427 trained in 67.92 seconds
# * Step kmeans_features will try to check up to 3 models
# 30_CatBoost_KMeansFeatures mae 57.64363 trained in 33.79 seconds
# 29_CatBoost_KMeansFeatures mae 56.567337 trained in 165.07 seconds
# 35_CatBoost_KMeansFeatures mae 56.319371 trained in 101.09 seconds
# * Step insert_random_feature will try to check up to 1 model
# 29_CatBoost_GoldenFeatures_RandomFeature mae 56.791615 trained in 126.65 seconds
# Drop features ['Delhi West', 'random_feature', 'Delhi Central', 'Independent House', 'Delhi North', 'Rohini', 'South West Delhi', 'North West Delhi', 'Villa']
# * Step features_selection will try to check up to 6 models
# 29_CatBoost_GoldenFeatures_SelectedFeatures mae 55.79671 trained in 108.21 seconds
# 19_Xgboost_SelectedFeatures mae 56.354629 trained in 6.24 seconds
# 5_Default_LightGBM_SelectedFeatures mae 56.576245 trained in 6.15 seconds
# 46_RandomForest_SelectedFeatures mae 62.142528 trained in 7.28 seconds
# 60_NeuralNetwork_SelectedFeatures mae 62.699797 trained in 6.97 seconds
# 52_ExtraTrees_SelectedFeatures mae 67.803113 trained in 5.79 seconds
# * Step hill_climbing_1 will try to check up to 29 models
# 65_CatBoost_GoldenFeatures mae 56.061806 trained in 58.23 seconds
# 66_CatBoost_GoldenFeatures mae 55.786047 trained in 160.25 seconds
# 67_CatBoost mae 56.326247 trained in 11.56 seconds
# 68_CatBoost mae 56.180055 trained in 24.08 seconds
# 69_CatBoost mae 55.848349 trained in 24.97 seconds
# 70_CatBoost mae 55.597166 trained in 79.55 seconds
# 71_Xgboost mae 56.54626 trained in 8.46 seconds
# 72_Xgboost mae 56.262639 trained in 6.69 seconds
# 73_Xgboost_SelectedFeatures mae 56.611943 trained in 6.93 seconds
# 74_Xgboost_SelectedFeatures mae 56.511038 trained in 7.36 seconds
# 75_Xgboost mae 56.534955 trained in 6.24 seconds
# 76_Xgboost mae 56.341985 trained in 6.17 seconds
# 77_LightGBM mae 56.901568 trained in 5.5 seconds
# 78_LightGBM_SelectedFeatures mae 57.190143 trained in 4.74 seconds
# 79_LightGBM mae 56.776663 trained in 4.92 seconds
# 80_RandomForest_SelectedFeatures mae 62.140545 trained in 7.06 seconds
# 81_RandomForest mae 62.269128 trained in 8.19 seconds
# 82_RandomForest mae 62.458616 trained in 7.6 seconds
# 83_RandomForest mae 62.547313 trained in 8.42 seconds
# 84_NeuralNetwork_SelectedFeatures mae 63.765819 trained in 6.82 seconds
# 85_NeuralNetwork_SelectedFeatures mae 62.878103 trained in 9.64 seconds
# 86_NeuralNetwork mae 63.144836 trained in 9.0 seconds
# 87_NeuralNetwork mae 63.25152 trained in 9.29 seconds
# 88_NeuralNetwork mae 63.499163 trained in 9.31 seconds
# 89_ExtraTrees mae 68.156437 trained in 6.67 seconds
# 90_ExtraTrees_SelectedFeatures mae 68.458911 trained in 7.81 seconds
# 91_ExtraTrees mae 70.264828 trained in 6.72 seconds
# 92_ExtraTrees mae 68.206111 trained in 5.73 seconds
# 93_DecisionTree mae 94.339036 trained in 3.92 seconds
# * Step hill_climbing_2 will try to check up to 30 models
# 94_CatBoost_GoldenFeatures mae 55.701177 trained in 151.77 seconds
# 95_CatBoost_GoldenFeatures mae 55.828799 trained in 93.54 seconds
# 96_CatBoost mae 55.580911 trained in 84.45 seconds
# 97_CatBoost mae 55.694821 trained in 88.21 seconds
# 98_CatBoost mae 55.964265 trained in 45.22 seconds
# 99_Xgboost mae 56.545603 trained in 7.27 seconds
# 100_Xgboost mae 56.505168 trained in 7.04 seconds
# 101_Xgboost mae 56.377303 trained in 7.67 seconds
# 102_Xgboost mae 56.401909 trained in 6.88 seconds
# 103_LightGBM mae 56.782779 trained in 6.11 seconds
# 104_LightGBM mae 56.864644 trained in 6.42 seconds
# 105_LightGBM_SelectedFeatures mae 56.645632 trained in 6.16 seconds
# 106_LightGBM_SelectedFeatures mae 56.838622 trained in 6.27 seconds
# 107_LightGBM mae 56.61244 trained in 6.57 seconds
# 108_LightGBM mae 56.942875 trained in 6.69 seconds
# 109_RandomForest_SelectedFeatures mae 62.324576 trained in 7.91 seconds
# 110_RandomForest_SelectedFeatures mae 62.366148 trained in 8.09 seconds
# 111_RandomForest mae 62.41892 trained in 9.18 seconds
# 112_NeuralNetwork_SelectedFeatures mae 63.680874 trained in 7.39 seconds
# 113_NeuralNetwork_SelectedFeatures mae 63.22701 trained in 8.34 seconds
# 114_NeuralNetwork mae 64.379272 trained in 6.97 seconds
# 115_ExtraTrees mae 67.485616 trained in 6.94 seconds
# 116_ExtraTrees mae 67.697464 trained in 6.88 seconds
# 117_ExtraTrees_SelectedFeatures mae 67.784129 trained in 8.75 seconds
# 118_ExtraTrees_SelectedFeatures mae 68.193343 trained in 7.16 seconds
# 119_ExtraTrees mae 68.00675 trained in 7.76 seconds
# 120_ExtraTrees mae 68.037167 trained in 7.08 seconds
# 121_DecisionTree mae 78.803097 trained in 4.81 seconds
# 122_DecisionTree mae 78.803097 trained in 4.81 seconds
# 123_DecisionTree mae 84.339544 trained in 4.82 seconds
# * Step boost_on_errors will try to check up to 1 model
# 29_CatBoost_GoldenFeatures_BoostOnErrors mae 55.874306 trained in 128.44 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble mae 54.719689 trained in 28.46 seconds
# * Step stack will try to check up to 60 models
# 29_CatBoost_GoldenFeatures_Stacked mae 56.018138 trained in 72.17 seconds
# 19_Xgboost_Stacked mae 56.186316 trained in 12.67 seconds
# 5_Default_LightGBM_Stacked mae 56.427102 trained in 7.97 seconds
# 80_RandomForest_SelectedFeatures_Stacked mae 55.489858 trained in 25.59 seconds
# 60_NeuralNetwork_SelectedFeatures_Stacked mae 178.695566 trained in 21.47 seconds
# 115_ExtraTrees_Stacked mae 55.234396 trained in 13.93 seconds
# 96_CatBoost_Stacked mae 56.090293 trained in 113.13 seconds
# 72_Xgboost_Stacked mae 56.309382 trained in 16.95 seconds
# 5_Default_LightGBM_SelectedFeatures_Stacked mae 56.44873 trained in 7.93 seconds
# 46_RandomForest_SelectedFeatures_Stacked mae 55.478147 trained in 23.67 seconds
# 85_NeuralNetwork_SelectedFeatures_Stacked mae 977.036219 trained in 17.06 seconds
# 52_ExtraTrees_Stacked mae 55.3013 trained in 13.44 seconds
# 70_CatBoost_Stacked mae 56.035855 trained in 114.03 seconds
# 76_Xgboost_Stacked mae 57.085885 trained in 13.62 seconds
# 107_LightGBM_Stacked mae 56.469121 trained in 7.92 seconds
# 46_RandomForest_Stacked mae 55.454861 trained in 21.43 seconds
# 60_NeuralNetwork_Stacked mae 1102.017779 trained in 23.46 seconds
# 116_ExtraTrees_Stacked mae 55.197365 trained in 15.16 seconds
# 97_CatBoost_Stacked mae 55.920832 trained in 92.1 seconds
# 19_Xgboost_SelectedFeatures_Stacked mae 56.230089 trained in 13.49 seconds
# 22_LightGBM_Stacked mae 56.688815 trained in 8.57 seconds
# 81_RandomForest_Stacked mae 55.486577 trained in 30.17 seconds
# 86_NeuralNetwork_Stacked mae 282.307052 trained in 27.11 seconds
# 117_ExtraTrees_SelectedFeatures_Stacked mae 55.195049 trained in 11.23 seconds
# 94_CatBoost_GoldenFeatures_Stacked mae 55.912463 trained in 69.02 seconds
# 101_Xgboost_Stacked mae 56.867882 trained in 18.8 seconds
# 105_LightGBM_SelectedFeatures_Stacked mae 56.417056 trained in 8.36 seconds
# 109_RandomForest_SelectedFeatures_Stacked mae 55.55838 trained in 22.21 seconds
# 113_NeuralNetwork_SelectedFeatures_Stacked mae 97.675885 trained in 18.35 seconds
# 52_ExtraTrees_SelectedFeatures_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 1.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# 30_CatBoost_Stacked not trained. Stop training after the first fold. Time needed to train on the first fold 4.0 seconds. The time estimate for training on all folds is larger than total_time_limit.
# * Step ensemble_stacked will try to check up to 1 model
# Ensemble_Stacked mae 54.662216 trained in 42.62 seconds
# AutoML fit time: 3672.02 seconds
# AutoML best model: Ensemble_Stacked
# AutoML(eval_metric='mae', ml_task='regression', mode='Compete',
#        validation_strategy={'k_folds': 5, 'shuffle': True, 'stratify': True,
#                             'validation_type': 'kfold'})

# %%
# 생성된 모델로 test 예측하기
pred = automl.predict(x_test)
submission['monthlyRent(us_dollar)'] = pred
# 제출파일 생성
submission.to_csv('./result_20221223_log.csv', index=False)
